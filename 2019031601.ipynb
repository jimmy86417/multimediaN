# %%
import sys
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

if __name__ =="__main__":
  if len(sys.argv)>1:
    image = cv2.imread('/content/drive/My Drive/pic/p2.jpg',cv2 .IMREAD_GRAYSCALE)
  else:
    print("Usge:python imgToArray.py imageFile")
  plt.imshow(image,cmap='gray')
  plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image2 = cv2.imread('/content/drive/My Drive/pic/p2.jpg', cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))
plt.show()

# %%
image4 = cv2.imread('/content/drive/My Drive/pic/p2.jpg', 0)
plt.imshow(image4)
plt.title('invert')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image5 = cv2.imread('/content/drive/My Drive/pic/p2.jpg')
gray = cv2.cvtColor(image5, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[128,  37,  36, ..., 197, 195, 197],
#        [126,  37,  36, ..., 198, 197, 194],
#        [127,  39,  39, ..., 202, 202, 197],
#        ...,
#        [121,  78,  45, ..., 111, 110, 107],
#        [128, 205, 201, ..., 104, 109, 107],
#        [125,   1,   1, ...,   0,   0,   0]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')
plt.title('gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image6 = cv2.imread('/content/drive/My Drive/pic/p2.jpg')
b , g, r = cv2.split(image6)
img = cv2.merge((r ,g , b))
plt.imshow(img)
plt.title('color')
plt.xticks([])
plt.yticks([])
plt.show()
